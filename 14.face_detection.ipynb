# %%
import cv2
print(cv2.__version__)
# Out:
# 4.1.2

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

prototxt = './deploy.prototxt'
model = './res10_300x300_ssd_iter_140000.caffemodel'
image = './image.jpg'
conf = 0.5


net = cv2.dnn.readNetFromCaffe(prototxt, model)
image = cv2.imread(image)
plt.imshow(image[:, :, ::-1])
(h, w) = image.shape[:2]
blob = cv2.dnn.blobFromImage(cv2.resize(image, (300, 300)), 1.0,(300, 300), (104.0, 177.0, 123.0))
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-7-f76d241fdbf5> in <module>()
#       9
#      10
# ---> 11 net = cv2.dnn.readNetFromCaffe(prototxt, model)
#      12 image = cv2.imread(image)
#      13 plt.imshow(image[:, :, ::-1])
#
# error: OpenCV(4.1.2) /io/opencv/modules/dnn/src/caffe/caffe_io.cpp:1121: error: (-2:Unspecified error) FAILED: fs.is_open(). Can't open "./deploy.prototxt" in function 'ReadProtoFromTextFile'

# %%
net.setInput(blob)
detections = net.forward()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-61dce2df623c> in <module>()
# ----> 1 net.setInput(blob)
#       2 detections = net.forward()
#
# NameError: name 'net' is not defined

# %%
for i in range(0, detections.shape[2]):
    confidence = detections[0, 0, i, 2]
    if confidence > conf:
        box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
        (startX, startY, endX, endY) = box.astype("int")
        text = "{:.2f}%".format(confidence * 100)
        y = startY - 10 if startY - 10 > 10 else startY + 10
        cv2.rectangle(image, (startX, startY), (endX, endY),(0, 0, 255), 2)
        cv2.putText(image, text, (startX, y),
        cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 0, 255), 2)
plt.imshow(image[:, :, ::-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-a16b8f0aa484> in <module>()
# ----> 1 for i in range(0, detections.shape[2]):
#       2     confidence = detections[0, 0, i, 2]
#       3     if confidence > conf:
#       4         box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
#       5         (startX, startY, endX, endY) = box.astype("int")
#
# NameError: name 'detections' is not defined
